# %%
import pandas as pd

# %%
ex = pd.read_csv("C:\\Users\\kikus\\Documents\\統数研\\pwscup2025-scripts\\out\\C01_inferred_ex.csv", header=None)

# %%
ex
# Out:
#        0       1
# 0      0  1000.0
# 1      0  1000.0
# 2      0  1000.0
# 3      0  1000.0
# 4      0  1000.0
# ...   ..     ...
# 99995  0  1000.0
# 99996  0  1000.0
# 99997  0  1000.0
# 99998  0  1000.0
# 99999  0  1000.0
#
# [100000 rows x 2 columns]

# %%
inferred = ex.iloc[:, 0]
inferred[inferred > 0] = 1
# Out:
# 25       1
# 47       1
# 165      1
# 204      1
# 337      1
#         ..
# 99843    1
# 99869    1
# 99943    1
# 99973    1
# 99981    1
# Name: 0, Length: 1972, dtype: int64

# %%
inferred
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 99995    0
# 99996    0
# 99997    0
# 99998    0
# 99999    0
# Name: 0, Length: 100000, dtype: int64

# %%
inferred.to_csv("C:\\Users\\kikus\\Documents\\統数研\\pwscup2025-scripts\\out\\C01_inferred.csv", index=False, header=False)
